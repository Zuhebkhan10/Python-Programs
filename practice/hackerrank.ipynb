# %%
n = int(input())
t = tuple(map(int,input().split()))
print(hash(t))
# Out:
#  1 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 n = int(input())
#       2 t = tuple(map(int,input().split()))
#       3 print(hash(t))
#
# ValueError: invalid literal for int() with base 10: '1 2'

# %%
# input().split() → reads space-separated values
# map(int, ...) → converts them to integers
# tuple(...) → creates a tuple
# hash(t) → returns the hash value of the tuple
# print() → displays the result


N = int(input())
t = tuple(map(int,input().split()))
print(hash(t))
# Out:
#  2
#  12
# -860454829093830431
