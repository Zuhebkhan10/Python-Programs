# %%
# An iterator is an object that contains a countable number of values.

#Return an iterator from a tuple, and print each value:
name=("Fahad","Kaif","Vamshi","Zuheb","Shahzain")
# print(name)

func=iter(name)
print(next(func))
print(next(func))
print(next(func))
print(next(func))
print(next(func))
# Out:
# ('Fahad', 'Kaif', 'Vamshi', 'Zuheb', 'Shahzain')
# Fahad
# Kaif
# Vamshi
# Zuheb
# Shahzain

# %%
# Iterate the values of a tuple:
mobile=("Oneplus","MI","OPPO","SAMSUNG","VIVO","IPHONE")
for i in mobile:
    print(i,end=" ")
# Out:
# Oneplus MI OPPO SAMSUNG VIVO IPHONE

# %%
# iterate the characters of a string:
char="Oneplus"
for i in char:
    print(i,end=" ")
# Out:
# O n e p l u s

# %%
# Using the sep 
l=["vamshi","zuheb"]
print(*l,sep=" & ")
# Out:
# vamshi & zuheb

# %%
# create an iterator that  returns numbers, starting with 1, and each sequence will increase by one
# (returning 1,2,3,4,5 etc.):
class numbers:
    def __iter__(self):
        self.a=1
        return self

    def __next__(self):
        b=self.a
        self.a+=1
        return x

myclass=numbers()
myiter=iter(myclass )
# Out:
#   Cell In[46], line 1
#     create an iterator that  returns numbers, starting with 1, and each sequence will increase by one (returning 1,2,3,4,5 etc.):
#            ^
# SyntaxError: invalid syntax

# %%
happiness=1
money=1000

def lifeBeing():
    if(money>=1000000):
        happiness=True
        print(happiness)
    else:
        happiness=False
        print(happiness)
