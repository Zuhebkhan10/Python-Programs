# %%
s1={10,20,30,40}
s2={45,50,60,10,50,70,20}
print(s1.issubset(s2))
print(s2.issubset(s1))
# Out:
# False
# False

# %%
data=[x for in range(5)]
temp=[x for x in range(7) if x in data and x%2==0]
print(temp)
# Out:
#   Cell In[6], line 1
#     data=[x for in range(5)]
#                 ^
# SyntaxError: invalid syntax

# %%
data = [x for x in range(5)]
temp = [x for x in range(7) if x in data and x%2==0]
print(temp)
# Out:
# [0, 2, 4]

# %%
l=[20,30,40,50]
print(l[::-2])
# Out:
# [50, 30]

# %%
for i in range(5):
    print(i,end=" ")
# Out:
# 0 1 2 3 4

# %%
l1=[10,20,30,40]
l1[1:4]=[50,60,70]
print(l1)
# Out:
# [10, 50, 60, 70]

# %%
# List comprehensions-generates
square=[x**2 for x in range(10)]
print(square)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
f={'a':1,'b':2}
f['c']=3
print(f)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
l=[10,20,30,40,50,60,70]
print(l[2:5])
# Out:
# [30, 40, 50]

# %%
str="python"
print(str[1:])
# Out:
# yth

# %%
def func(f,l):
    print(f+" "+l)
func("zuheb","khan")
# Out:
# zuheb khan

# %%
x=10
y=x
y=20
print(x)
# Out:
# 10

# %%
if n<=0:
    print("Done")
else:
    print(n)
    cd(n-1)
cd(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 if n<=0:
#       2     print("Done")
#       3 else:
#
# NameError: name 'n' is not defined

# %%
c={"Yellow","Orange","Black"}
c.discard("Blue")
print(c)
# Out:
# {'Yellow', 'Orange', 'Black'}

# %%
s={1,'PYnative',('abc','xyz'),True}
print(s)
# Out:
# {1, ('abc', 'xyz'), 'PYnative'}

# %%
s1={"Yellow","Orange","Black"}
s2={"Orange","Blue","Pink"}
s3=s2.difference(s1)
print(s3)
# Out:
# {'Pink', 'Blue'}

# %%
for i in range(5):
    print(i)
    else:
    print("Done")
# Out:
#   Cell In[30], line 3
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
s1={10,20,30,40}
s2={50,20,"10",60}
s3=s1.union(s2)
print(s3)
# Out:
# {40, 10, 50, 20, 60, 30, '10'}

# %%
l=["Physic","Chemistry",1100,2000]
print(l[1][-1])
# Out:
# y

# %%
s="Zuheb"
print(s[1:5:1])
# Out:
# uheb
