# %%
# Decorator is a function that takes a function it creates a new function inside its body (wrapper)
# then it returns that new function.
def decorator(func):
    def wrapper():
        print("Toh kaise h aapp ")
        func()
        print("Sb thik thak changaa h mamla")
    return wrapper
    
@decorator
def say():
    print("Sabhii paltan")

say()
# s=decorator(say)
# s()
# Out:
# Toh kaise h aapp
# Sabhii paltan
# Sb thik thak changaa h mamla

# %%
# Using Decorators with Arguments
"""Decorators themselves can also accept arguments. This requires another level of nesting: an outer function that takes the decorator's arguments and returns the
actual decorator function."""


def repeat(n):
    def decorator(func):
        def wrapper(a):
            for i in range(n):
                func(a)
        return wrapper
    return decorator

@repeat(7)
def say(a):
    print(f"Hey {a}")

say("gulam gulam gulam ki kali panni band nhi ho rhi ")
# Out:
# Hey gulam gulam gulam ki kali panni band nhi ho rhi
# Hey gulam gulam gulam ki kali panni band nhi ho rhi
# Hey gulam gulam gulam ki kali panni band nhi ho rhi
# Hey gulam gulam gulam ki kali panni band nhi ho rhi
# Hey gulam gulam gulam ki kali panni band nhi ho rhi
# Hey gulam gulam gulam ki kali panni band nhi ho rhi
# Hey gulam gulam gulam ki kali panni band nhi ho rhi
