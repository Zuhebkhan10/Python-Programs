# %%
#how can we create an class.
#what is attribute and how many types of attributes do we have.

#these are nothing the data that we are defining in class and object. 
# 2-type of attributes
# class-attributes:These are the common properties where anyone can access.
# object-attributes:These are unique properties where it can access by specific object.

# what is a method
# methods are nothing but functions created inside the class. 

#what is a self?
#self is a pointer or referencer where it is used to access the particular data or information

#step1: create class and create object
#step2: create class and object attributes and access it
# Out:
#   Cell In[1], line 10
#     methods are nothing but functions created inside the class.
#             ^
# SyntaxError: invalid syntax

# %%
class Customer:
    def __init__(self, name, balance, acc_no, city):
        self.name = name
        self.balance = balance
        self.acc_no = acc_no
        self.city = city

    def display(self):
        print("Name:", self.name)
        print("Balance:", self.balance)
        print("Account No:", self.acc_no)
        print("City:", self.city)


c1 = Customer("Shahzain", 20000, 340001211, "Sohawal")
c1.display()
# Out:
# Name: Shahzain
# Balance: 20000
# Account No: 340001211
# City: Sohawal
