# %%
#what is Function?
#Function is a block of code which can be executed when we call it

#what is the purpose of functions?
#to avoid the duplication of codes we use the functions

#How can we create a function?
#to create the function we need to use "def"


#create a function to print hello world!?
def func():
  print("hello duniya")
#call the function
func()
print(type(func()))

# %%
#create a functiuon where it prints name
def details(name):
    print(name)
details("Pathan")    

#when we define a function we create a variable which is known as parameters
#when we call the function we pass some values which is known as arguments
# Out:
# Pathan

# %%
#How many parameters and arguments can we pass
#The No of parameters we created == No of arguments we pass
def details(name,gender,age,address):
  print(f"Hello {name}, please check your details gender : {gender} age: {age} and address : {address}")

#call the function
details("Duffy","Female","21","New york")
# Out:
# Hello Duffy, please check your details gender : Female age: 21 and address : New york

# %%
#create a function with one parameter and call the function without giving the argument
# but don't rise the error
def f3(name="user"):
  print(f"hello {name}! welcome to python session")
  pass

f3("Duffy")
#Default functions:- when we define a function we create a variable(parameter) and by default
# we assign a value
# Out:
# hello Duffy! welcome to python session

# %%
#worst case
a = 60
b = 70
c = 55
d = 42
e = 95
#check the above numbers is a even number or odd number
if a%2==0:
  print("even")
else:
  print("odd")

if b%2==0:
  print("even")
else:
  print("odd")

if c%2==0:
  print("even")
else:
  print("odd")

if d%2==0:
  print("even")
else:
  print("odd")

if e%2==0:
  print("even")
else:
  print("odd")
# Out:
# even
# even
# odd
# even
# odd

# %%
# using list for loop check the even or odd
list=[10,22,33,44,70,73,29,90]
for i in list:
    if i%2==0:
        print("Even num is :",i)
    else:
        print("Odd num is :",i)
# Out:
# Even num is : 10
# Even num is : 22
# Odd num is : 33
# Even num is : 44
# Even num is : 70
# Odd num is : 73
# Odd num is : 29
# Even num is : 90

# %%
# check the even or odd using function.
a=10
b=22
c=33
d=90
e=21

def check_num(num):
    if num%2==0:
        print("Even num is :",num)
    else:
         print("Odd num is :",num)
check_num(a) 
check_num(b)
check_num(c)
check_num(d)
check_num(e)
# Out:
# Even num is : 10
# Even num is : 22
# Odd num is : 33
# Even num is : 90
# Odd num is : 21

# %%
# Check the list for function using even or odd

l=[21,33,44,55,65,10]
def check(num):
    for i in num:
        if i%2==0:
            print("Even num is",i)
        else:
            print("Odd num is ",i)      
check(l)
# Out:
# Odd num is  21
# Odd num is  33
# Even num is 44
# Odd num is  55
# Odd num is  65
# Even num is 10
